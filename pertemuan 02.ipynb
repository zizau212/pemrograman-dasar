# %% [markdown]
# <a href="https://colab.research.google.com/github/zizau212/pemrograman-dasar/blob/main/pertemuan%2002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#latihan 1
#panel surya
tegangan = 18
arus = 6
jenis_sel = "monocrstalline"

#mencetak nilai
print(tegangan)
print(arus)
print(jenis_sel)

#latihan 2
#komponen elektronika
resistor = 10 #integer
kapasitor = 16.5 #float
led_active = True #bool
mikrokontroler = "ESP32 WROOM" #string

#mencetak nilai
print("Nilai",resistor,"Tipe:",type(resistor))
print("Nilai",kapasitor,"Tipe",type(kapasitor))
print("Nilai",led_active,"tipe",type(led_active))
print("Nilai",mikrokontroler,"tipe",type(mikrokontroler))

#latihan 3
# Membuat variabel dan mengisi data
nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(type(nama_unit))
print(type(jumlah_panel))
print(type(tegangan_keluaran))
print(type(sedang_beroperasi))

#latihan 4
#A
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]
print("pembacaan pertama",tegangan_harian[0])
print("pembacaan terakhir",tegangan_harian[-1])
#B
tegangan_harian.append(222.0)
#C
print(len(tegangan_harian))

#latihan 5
motor_listrik = {
"nama": "Motor Induksi 3 Fasa",
"daya_kW": 5.5,
"tegangan_V": 380,
"rpm": 1500
}

# Cetak salah satu nilai lewat key
print(motor_listrik["daya_kW"])

# Ubah nilai rpm
motor_listrik["rpm"] = 1800

# Cetak seluruh dictionary
print(motor_listrik)

#latihan 6
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]

# Cetak nama unit kedua
print(pembangkit[1]["nama"])

# Ubah status Unit-1
pembangkit[0]["status"] = "pemeliharaan"

# Tambahkan unit baru
pembangkit.append({
    "nama": "Unit-4",
    "kapasitas_MW": 200,
    "status": "operasi"
})

# Cetak seluruh data
print(pembangkit)
# Out:
# 18
# 6
# monocrstalline
# Nilai 10 Tipe: <class 'int'>
# Nilai 16.5 Tipe <class 'float'>
# Nilai True tipe <class 'bool'>
# Nilai ESP32 WROOM tipe <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# pembacaan pertama 217.5
# pembacaan terakhir 216.9
# 7
# 5.5
# {'nama': 'Motor Induksi 3 Fasa', 'daya_kW': 5.5, 'tegangan_V': 380, 'rpm': 1800}
# Unit-2
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'pemeliharaan'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'pemeliharaan'}, {'nama': 'Unit-4', 'kapasitas_MW': 200, 'status': 'operasi'}]
